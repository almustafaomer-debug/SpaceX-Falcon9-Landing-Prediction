# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/Falcon9_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_1_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
#   ## Objectives
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
# - Extract a Falcon 9 launch records HTML table from Wikipedia
# - Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2023.5.7)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/91.0.4472.124 Safari/537.36"
}

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
import requests

# 1. Target URL for the Falcon 9 Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"

# 2. Perform the HTTP GET request
response = requests.get(url)

# 3. Check the HTTP status code (200 means SUCCESS!)
print("Status Code:", response.status_code)
# Out:
# Status Code: 403

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/bs4/__init__.py:439: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   MarkupResemblesLocatorWarning

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
url = "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"

# Pass a User-Agent header so Wikipedia treats you like a real browser
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)

# Check status code (should be 200!)
print("Status Code:", response.status_code)

# Parse HTML
soup = BeautifulSoup(response.text, 'html.parser')

# Verify title now
print("Page Title:", soup.title.string)
# Out:
# Status Code: 200
# Page Title: List of Falcon 9 and Falcon Heavy launches - Wikipedia

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('table')
len(html_tables)
# Out:
# 15

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
print(first_launch_table)
# Out:
# <table class="wikitable plainrowheaders collapsible sticky-header" id="2026ytd" style="width: 100%;">
# <tbody id="mwGGk"><tr id="mwGGo"><th id="mwGGs" scope="col">Flight No.</th>
# <th id="mwGGw" scope="col">Date and<br id="mwGG0"/>time (<a href="https://en.wikipedia.org/wiki/Coordinated_Universal_Time" id="mwGG4" rel="mw:WikiLink" title="Coordinated Universal Time">UTC</a>)</th>
# <th id="mwGG8" scope="col"><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters" id="mwGHA" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">Version,<br id="mwGHE"/>booster</a><sup about="#mwt2594" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"booster","group":"lower-alpha"},"body":{"html":""},"parts":[{"template":{"target":{"wt":"efn","href":"./Template:Efn"},"params":{"name":{"wt":"booster"}},"i":0}}]}' id="cite_ref-booster_37-1" rel="dc:references" typeof="mw:Transclusion mw:Extension/ref"><a data-mw-group="lower-alpha" href="#cite_note-booster-37" id="mwGHI"><span class="mw-reflink-text" id="mwGHM"><span class="cite-bracket" id="mwGHQ">[</span>i<span class="cite-bracket" id="mwGHU">]</span></span></a></sup></th>
# <th id="mwGHY" scope="col">Launch<br id="mwGHc"/>site</th>
# <th id="mwGHg" scope="col">Payload<sup about="#mwt2597" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"Dragon","group":"lower-alpha"},"body":{"html":""},"parts":[{"template":{"target":{"wt":"efn","href":"./Template:Efn"},"params":{"name":{"wt":"Dragon"}},"i":0}}]}' id="cite_ref-Dragon_38-1" rel="dc:references" typeof="mw:Transclusion mw:Extension/ref"><a data-mw-group="lower-alpha" href="#cite_note-Dragon-38" id="mwGHk"><span class="mw-reflink-text" id="mwGHo"><span class="cite-bracket" id="mwGHs">[</span>j<span class="cite-bracket" id="mwGHw">]</span></span></a></sup></th>
# <th id="mwGH0" scope="col">Payload mass</th>
# <th id="mwGH4" scope="col">Orbit</th>
# <th id="mwGH8" scope="col">Customer</th>
# <th id="mwGIA" scope="col">Launch<br id="mwGIE"/>outcome</th>
# <th id="mwGII" scope="col"><a href="https://en.wikipedia.org/wiki/Falcon_9_first-stage_landing_tests" id="mwGIM" rel="mw:WikiLink" title="Falcon 9 first-stage landing tests">Booster<br id="mwGIQ"/>landing</a></th></tr>
# <tr id="F9-583">
# <th id="mwGIU" rowspan="2" scope="row" style="text-align:center;">583</th>
# <td id="mwGIY"><span about="#mwt2600" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 3, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-03-0000" id="mwGIc" style="white-space:nowrap" typeof="mw:Transclusion">January 3, 2026</span><br id="mwGIg"/>02:09<sup about="#mwt2603" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-264"}}' id="cite_ref-264" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-264" id="mwGIk"><span class="mw-reflink-text" id="mwGIo"><span class="cite-bracket" id="mwGIs">[</span>253<span class="cite-bracket" id="mwGIw">]</span></span></a></sup></td>
# <td id="mwGI0"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGI4" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2606" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGI8" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGJA"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1081" id="mwGJE" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1081<span about="#mwt2605" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGJI" typeof="mw:Transclusion mw:Entity">‑</span>21</a></td>
# <td id="mwGJM"><a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Force_Base" id="mwGJQ" rel="mw:WikiLink" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Launch_Complex_4" id="mwGJU" rel="mw:WikiLink" title="Vandenberg Space Launch Complex 4">SLC<span about="#mwt2608" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGJY" typeof="mw:Transclusion mw:Entity">‑</span>4E</a></td>
# <td id="mwGJc"><a href="https://en.wikipedia.org/wiki/COSMO-SkyMed" id="mwGJg" rel="mw:WikiLink" title="COSMO-SkyMed">CSG-3</a></td>
# <td id="mwGJk"><span about="#mwt2609" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"2230"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGJo" typeof="mw:Transclusion">2,230</span><span about="#mwt2609" typeof="mw:Entity"> </span><span about="#mwt2609">kg (4,920</span><span about="#mwt2609" typeof="mw:Entity"> </span><span about="#mwt2609">lb)</span></td>
# <td id="mwGJs"><a href="https://en.wikipedia.org/wiki/Sun-synchronous_orbit" id="mwGJw" rel="mw:WikiLink" title="Sun-synchronous orbit">SSO</a></td>
# <td id="mwGJ0"><a href="https://en.wikipedia.org/wiki/Italian_Space_Agency" id="mwGJ4" rel="mw:WikiLink" title="Italian Space Agency">ASI</a></td>
# <td about="#mwt2610" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGJ8" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2611" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[SpaceX Landing Zone 4|LZ{{nbhyph}}4]])"]}' id="mwGKA" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/SpaceX_Landing_Zone_4" rel="mw:WikiLink" title="SpaceX Landing Zone 4">LZ<span about="#mwt2613" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' typeof="mw:Transclusion mw:Entity">‑</span>4</a>)</td></tr>
# <tr id="mwGKE">
# <td colspan="9" id="mwGKI">Third <a href="https://en.wikipedia.org/wiki/COSMO-SkyMed#COSMO-SkyMed_second_generation_(CSG)" id="mwGKM" rel="mw:WikiLink" title="COSMO-SkyMed">COSMO-SkyMed 2nd-generation</a> satellite. 100th Falcon booster ground pad landing.</td></tr>
# <tr id="F9-584">
# <th id="mwGKQ" rowspan="2" scope="row" style="text-align:center;">584</th>
# <td id="mwGKU"><span about="#mwt2614" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 4, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-04-0000" id="mwGKY" style="white-space:nowrap" typeof="mw:Transclusion">January 4, 2026</span><br id="mwGKc"/>06:48<sup about="#mwt2617" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-265"}}' id="cite_ref-265" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-265" id="mwGKg"><span class="mw-reflink-text" id="mwGKk"><span class="cite-bracket" id="mwGKo">[</span>254<span class="cite-bracket" id="mwGKs">]</span></span></a></sup></td>
# <td id="mwGKw" style="background:#D1F2EB"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGK0" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2620" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGK4" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGK8"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1101" id="mwGLA" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1101<span about="#mwt2619" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGLE" typeof="mw:Transclusion mw:Entity">‑</span>1</a></td>
# <td id="mwGLI"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwGLM" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwGLQ" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt2622" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGLU" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwGLY"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGLc" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G6-88" id="mwGLg" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGLk" typeof="mw:Entity"> </span>6-88</a></td>
# <td id="mwGLo">~<span about="#mwt2623" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGLs" typeof="mw:Transclusion">16,675</span><span about="#mwt2623" typeof="mw:Entity"> </span><span about="#mwt2623">kg (36,762</span><span about="#mwt2623" typeof="mw:Entity"> </span><span about="#mwt2623">lb)</span></td>
# <td id="mwGLw"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwGL0" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwGL4"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGL8" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2624" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGMA" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2625" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[Just Read the Instructions|JRTI]])"]}' id="mwGME" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/Just_Read_the_Instructions" rel="mw:WikiLink" title="Just Read the Instructions">JRTI</a>)</td></tr>
# <tr id="mwGMI">
# <td colspan="9" id="mwGMM">Launch of 29 Starlink v2<span about="#mwt2626" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGMQ" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini optimized satellites to a <span about="#mwt2627" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"559"},"2":{"wt":"km"}},"i":0}}]}' id="mwGMU" typeof="mw:Transclusion">559</span><span about="#mwt2627" typeof="mw:Entity"> </span><span about="#mwt2627">km (347</span><span about="#mwt2627" typeof="mw:Entity"> </span><span about="#mwt2627">mi)</span> orbit at an inclination of 43° to expand internet constellation.</td></tr>
# <tr id="F9-585">
# <th id="mwGMY" rowspan="2" scope="row" style="text-align:center;">585</th>
# <td id="mwGMc"><span about="#mwt2628" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 9, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-09-0000" id="mwGMg" style="white-space:nowrap" typeof="mw:Transclusion">January 9, 2026</span><br id="mwGMk"/>21:41<sup about="#mwt2631" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-266"}}' id="cite_ref-266" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-266" id="mwGMo"><span class="mw-reflink-text" id="mwGMs"><span class="cite-bracket" id="mwGMw">[</span>255<span class="cite-bracket" id="mwGM0">]</span></span></a></sup></td>
# <td id="mwGM4"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGM8" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2634" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGNA" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGNE"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1069" id="mwGNI" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1069<span about="#mwt2633" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGNM" typeof="mw:Transclusion mw:Entity">‑</span>29</a></td>
# <td id="mwGNQ"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwGNU" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwGNY" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt2636" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGNc" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwGNg"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGNk" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G6-96" id="mwGNo" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGNs" typeof="mw:Entity"> </span>6-96</a></td>
# <td id="mwGNw">~<span about="#mwt2637" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGN0" typeof="mw:Transclusion">16,675</span><span about="#mwt2637" typeof="mw:Entity"> </span><span about="#mwt2637">kg (36,762</span><span about="#mwt2637" typeof="mw:Entity"> </span><span about="#mwt2637">lb)</span></td>
# <td id="mwGN4"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwGN8" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwGOA"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGOE" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2638" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGOI" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2639" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[A Shortfall of Gravitas|ASOG]])"]}' id="mwGOM" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/A_Shortfall_of_Gravitas" rel="mw:WikiLink" title="A Shortfall of Gravitas">ASOG</a>)</td></tr>
# <tr id="mwGOQ">
# <td colspan="9" id="mwGOU">Launch of 29 Starlink v2<span about="#mwt2640" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGOY" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini optimized satellites to a <span about="#mwt2641" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"559"},"2":{"wt":"km"}},"i":0}}]}' id="mwGOc" typeof="mw:Transclusion">559</span><span about="#mwt2641" typeof="mw:Entity"> </span><span about="#mwt2641">km (347</span><span about="#mwt2641" typeof="mw:Entity"> </span><span about="#mwt2641">mi)</span> orbit at an inclination of 43° to expand internet constellation.</td></tr>
# <tr id="F9-586">
# <th id="mwGOg" rowspan="2" scope="row" style="text-align:center;">586</th>
# <td id="mwGOk"><span about="#mwt2642" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 11, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-11-0000" id="mwGOo" style="white-space:nowrap" typeof="mw:Transclusion">January 11, 2026</span><br id="mwGOs"/>13:44<sup about="#mwt2645" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-267"}}' id="cite_ref-267" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-267" id="mwGOw"><span class="mw-reflink-text" id="mwGO0"><span class="cite-bracket" id="mwGO4">[</span>256<span class="cite-bracket" id="mwGO8">]</span></span></a></sup></td>
# <td id="mwGPA"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGPE" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2648" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGPI" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGPM"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1097" id="mwGPQ" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1097<span about="#mwt2647" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGPU" typeof="mw:Transclusion mw:Entity">‑</span>5</a></td>
# <td id="mwGPY"><a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Force_Base" id="mwGPc" rel="mw:WikiLink" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Launch_Complex_4" id="mwGPg" rel="mw:WikiLink" title="Vandenberg Space Launch Complex 4">SLC<span about="#mwt2650" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGPk" typeof="mw:Transclusion mw:Entity">‑</span>4E</a></td>
# <td id="mwGPo"><a href="https://en.wikipedia.org/wiki/List_of_spaceflight_launches_in_January–March_2026#SpXTwilight" id="mwGPs" rel="mw:WikiLink" title="List of spaceflight launches in January–March 2026">Twilight</a> (<a href="https://en.wikipedia.org/wiki/Pandora_(spacecraft)" id="mwGPw" rel="mw:WikiLink" title="Pandora (spacecraft)">Pandora</a> and others 39 payloads)</td>
# <td id="mwGP0"><span about="#mwt2651" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"325"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGP4" typeof="mw:Transclusion">325</span><span about="#mwt2651" typeof="mw:Entity"> </span><span about="#mwt2651">kg (717</span><span about="#mwt2651" typeof="mw:Entity"> </span><span about="#mwt2651">lb)</span><br id="mwGP8"/>(main satellite)</td>
# <td id="mwGQA"><a href="https://en.wikipedia.org/wiki/Sun-synchronous_orbit" id="mwGQE" rel="mw:WikiLink" title="Sun-synchronous orbit">SSO</a></td>
# <td id="mwGQI"><a href="https://en.wikipedia.org/wiki/NASA" id="mwGQM" rel="mw:WikiLink" title="NASA">NASA</a> &amp; Various</td>
# <td about="#mwt2652" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGQQ" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2653" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[SpaceX Landing Zone 4|LZ{{nbhyph}}4]])"]}' id="mwGQU" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/SpaceX_Landing_Zone_4" rel="mw:WikiLink" title="SpaceX Landing Zone 4">LZ<span about="#mwt2655" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' typeof="mw:Transclusion mw:Entity">‑</span>4</a>)</td></tr>
# <tr id="mwGQY">
# <td colspan="9" id="mwGQc">Dedicated SmallSat rideshare mission to sun-synchronous orbit.</td></tr>
# <tr id="F9-587">
# <th id="mwGQg" rowspan="2" scope="row" style="text-align:center;">587</th>
# <td id="mwGQk"><span about="#mwt2656" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 12, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-12-0000" id="mwGQo" style="white-space:nowrap" typeof="mw:Transclusion">January 12, 2026</span><br id="mwGQs"/>21:08<sup about="#mwt2659" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-268"}}' id="cite_ref-268" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-268" id="mwGQw"><span class="mw-reflink-text" id="mwGQ0"><span class="cite-bracket" id="mwGQ4">[</span>257<span class="cite-bracket" id="mwGQ8">]</span></span></a></sup></td>
# <td id="mwGRA"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGRE" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2662" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGRI" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGRM"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1078" id="mwGRQ" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1078<span about="#mwt2661" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGRU" typeof="mw:Transclusion mw:Entity">‑</span>25</a></td>
# <td id="mwGRY"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwGRc" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwGRg" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt2664" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGRk" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwGRo"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGRs" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G6-97" id="mwGRw" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGR0" typeof="mw:Entity"> </span>6-97</a></td>
# <td id="mwGR4">~<span about="#mwt2665" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGR8" typeof="mw:Transclusion">16,675</span><span about="#mwt2665" typeof="mw:Entity"> </span><span about="#mwt2665">kg (36,762</span><span about="#mwt2665" typeof="mw:Entity"> </span><span about="#mwt2665">lb)</span></td>
# <td id="mwGSA"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwGSE" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwGSI"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGSM" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2666" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGSQ" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2667" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[Just Read the Instructions|JRTI]])"]}' id="mwGSU" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/Just_Read_the_Instructions" rel="mw:WikiLink" title="Just Read the Instructions">JRTI</a>)</td></tr>
# <tr id="mwGSY">
# <td colspan="9" id="mwGSc">Launch of 29 Starlink v2<span about="#mwt2668" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGSg" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini optimized satellites to a <span about="#mwt2669" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"559"},"2":{"wt":"km"}},"i":0}}]}' id="mwGSk" typeof="mw:Transclusion">559</span><span about="#mwt2669" typeof="mw:Entity"> </span><span about="#mwt2669">km (347</span><span about="#mwt2669" typeof="mw:Entity"> </span><span about="#mwt2669">mi)</span> orbit at an inclination of 43° to expand internet constellation.</td></tr>
# <tr id="F9-588">
# <th id="mwGSo" rowspan="2" scope="row" style="text-align:center;">588</th>
# <td id="mwGSs"><span about="#mwt2670" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 14, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-14-0000" id="mwGSw" style="white-space:nowrap" typeof="mw:Transclusion">January 14, 2026</span><br id="mwGS0"/>18:08<sup about="#mwt2673" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-269"}}' id="cite_ref-269" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-269" id="mwGS4"><span class="mw-reflink-text" id="mwGS8"><span class="cite-bracket" id="mwGTA">[</span>258<span class="cite-bracket" id="mwGTE">]</span></span></a></sup></td>
# <td id="mwGTI"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGTM" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2676" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGTQ" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGTU"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1085" id="mwGTY" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1085<span about="#mwt2675" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGTc" typeof="mw:Transclusion mw:Entity">‑</span>13</a></td>
# <td id="mwGTg"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwGTk" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwGTo" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt2678" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGTs" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwGTw"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGT0" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G6-98" id="mwGT4" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGT8" typeof="mw:Entity"> </span>6-98</a></td>
# <td id="mwGUA">~<span about="#mwt2679" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGUE" typeof="mw:Transclusion">16,675</span><span about="#mwt2679" typeof="mw:Entity"> </span><span about="#mwt2679">kg (36,762</span><span about="#mwt2679" typeof="mw:Entity"> </span><span about="#mwt2679">lb)</span></td>
# <td id="mwGUI"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwGUM" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwGUQ"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGUU" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2680" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGUY" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2681" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[A Shortfall of Gravitas|ASOG]])"]}' id="mwGUc" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/A_Shortfall_of_Gravitas" rel="mw:WikiLink" title="A Shortfall of Gravitas">ASOG</a>)</td></tr>
# <tr id="mwGUg">
# <td colspan="9" id="mwGUk">Launch of 29 Starlink v2<span about="#mwt2682" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGUo" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini optimized satellites to a <span about="#mwt2683" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"559"},"2":{"wt":"km"}},"i":0}}]}' id="mwGUs" typeof="mw:Transclusion">559</span><span about="#mwt2683" typeof="mw:Entity"> </span><span about="#mwt2683">km (347</span><span about="#mwt2683" typeof="mw:Entity"> </span><span about="#mwt2683">mi)</span> orbit at an inclination of 43° to expand internet constellation. A new pad turnaround time record, launching 45 hours and 0 minutes after the previous mission.<sup about="#mwt2686" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-270"}}' id="cite_ref-270" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-270" id="mwGUw"><span class="mw-reflink-text" id="mwGU0"><span class="cite-bracket" id="mwGU4">[</span>259<span class="cite-bracket" id="mwGU8">]</span></span></a></sup></td></tr>
# <tr id="F9-589">
# <th id="mwGVA" rowspan="2" scope="row" style="text-align:center;">589</th>
# <td id="mwGVE"><span about="#mwt2687" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 17, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-17-0000" id="mwGVI" style="white-space:nowrap" typeof="mw:Transclusion">January 17, 2026</span><br id="mwGVM"/>04:39<sup about="#mwt2690" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-271"}}' id="cite_ref-271" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-271" id="mwGVQ"><span class="mw-reflink-text" id="mwGVU"><span class="cite-bracket" id="mwGVY">[</span>260<span class="cite-bracket" id="mwGVc">]</span></span></a></sup></td>
# <td id="mwGVg"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGVk" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2693" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGVo" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGVs"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1100" id="mwGVw" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1100<span about="#mwt2692" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGV0" typeof="mw:Transclusion mw:Entity">‑</span>2</a></td>
# <td id="mwGV4"><a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Force_Base" id="mwGV8" rel="mw:WikiLink" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Launch_Complex_4" id="mwGWA" rel="mw:WikiLink" title="Vandenberg Space Launch Complex 4">SLC<span about="#mwt2695" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGWE" typeof="mw:Transclusion mw:Entity">‑</span>4E</a></td>
# <td id="mwGWI"><a href="https://en.wikipedia.org/wiki/List_of_NRO_launches" id="mwGWM" rel="mw:WikiLink" title="List of NRO launches">NROL-105</a> (9<span id="mwGWQ" typeof="mw:Entity"> </span><a href="https://en.wikipedia.org/wiki/SpaceX_Starshield" id="mwGWU" rel="mw:WikiLink" title="SpaceX Starshield">Starshield</a> satellites)</td>
# <td about="#mwt2696" class="table-na" data-mw='{"parts":["| ",{"template":{"target":{"wt":"n/a","href":"./Template:N/a"},"params":{"1":{"wt":"Unknown"}},"i":0}}]}' data-sort-value="" id="mwGWY" style="background: var(--background-color-interactive, #ececec); color: var(--color-base, inherit); vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Unknown</td>
# <td id="mwGWc"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwGWg" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwGWk"><a href="https://en.wikipedia.org/wiki/National_Reconnaissance_Office" id="mwGWo" rel="mw:WikiLink" title="National Reconnaissance Office">NRO</a></td>
# <td about="#mwt2697" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGWs" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2698" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[SpaceX Landing Zone 4|LZ{{nbhyph}}4]])"]}' id="mwGWw" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/SpaceX_Landing_Zone_4" rel="mw:WikiLink" title="SpaceX Landing Zone 4">LZ<span about="#mwt2700" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' typeof="mw:Transclusion mw:Entity">‑</span>4</a>)</td></tr>
# <tr id="mwGW0">
# <td colspan="9" id="mwGW4">Twelfth batch SpaceX/Northrop Grumman-built Starshield satellites for the National Reconnaissance Office.</td></tr>
# <tr id="F9-590">
# <th id="mwGW8" rowspan="2" scope="row" style="text-align:center;">590</th>
# <td id="mwGXA"><span about="#mwt2701" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 18, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-18-0000" id="mwGXE" style="white-space:nowrap" typeof="mw:Transclusion">January 18, 2026</span><br id="mwGXI"/>23:31<sup about="#mwt2704" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-272"}}' id="cite_ref-272" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-272" id="mwGXM"><span class="mw-reflink-text" id="mwGXQ"><span class="cite-bracket" id="mwGXU">[</span>261<span class="cite-bracket" id="mwGXY">]</span></span></a></sup></td>
# <td id="mwGXc"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGXg" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2707" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGXk" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGXo"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1080" id="mwGXs" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1080<span about="#mwt2706" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGXw" typeof="mw:Transclusion mw:Entity">‑</span>24</a></td>
# <td id="mwGX0"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwGX4" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwGX8" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt2709" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGYA" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwGYE"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGYI" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G6-100" id="mwGYM" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGYQ" typeof="mw:Entity"> </span>6-100</a></td>
# <td id="mwGYU">~<span about="#mwt2710" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGYY" typeof="mw:Transclusion">16,675</span><span about="#mwt2710" typeof="mw:Entity"> </span><span about="#mwt2710">kg (36,762</span><span about="#mwt2710" typeof="mw:Entity"> </span><span about="#mwt2710">lb)</span></td>
# <td id="mwGYc"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwGYg" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwGYk"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGYo" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2711" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGYs" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2712" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[A Shortfall of Gravitas|ASOG]])"]}' id="mwGYw" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/A_Shortfall_of_Gravitas" rel="mw:WikiLink" title="A Shortfall of Gravitas">ASOG</a>)</td></tr>
# <tr id="mwGY0">
# <td colspan="9" id="mwGY4">Launch of 29 Starlink v2<span about="#mwt2713" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGY8" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini optimized satellites to a <span about="#mwt2714" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"559"},"2":{"wt":"km"}},"i":0}}]}' id="mwGZA" typeof="mw:Transclusion">559</span><span about="#mwt2714" typeof="mw:Entity"> </span><span about="#mwt2714">km (347</span><span about="#mwt2714" typeof="mw:Entity"> </span><span about="#mwt2714">mi)</span> orbit at an inclination of 43° to expand internet constellation.</td></tr>
# <tr id="F9-591">
# <th id="mwGZE" rowspan="2" scope="row" style="text-align:center;">591</th>
# <td id="mwGZI"><span about="#mwt2715" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 22, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-22-0000" id="mwGZM" style="white-space:nowrap" typeof="mw:Transclusion">January 22, 2026</span><br id="mwGZQ"/>05:47<sup about="#mwt2718" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-273"}}' id="cite_ref-273" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-273" id="mwGZU"><span class="mw-reflink-text" id="mwGZY"><span class="cite-bracket" id="mwGZc">[</span>262<span class="cite-bracket" id="mwGZg">]</span></span></a></sup></td>
# <td id="mwGZk"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGZo" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2721" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGZs" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGZw"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1093" id="mwGZ0" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1093<span about="#mwt2720" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGZ4" typeof="mw:Transclusion mw:Entity">‑</span>10</a></td>
# <td id="mwGZ8"><a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Force_Base" id="mwGaA" rel="mw:WikiLink" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Launch_Complex_4" id="mwGaE" rel="mw:WikiLink" title="Vandenberg Space Launch Complex 4">SLC<span about="#mwt2723" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGaI" typeof="mw:Transclusion mw:Entity">‑</span>4E</a></td>
# <td id="mwGaM"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGaQ" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G17-30" id="mwGaU" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGaY" typeof="mw:Entity"> </span>17-30</a></td>
# <td id="mwGac">~<span about="#mwt2724" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"14375"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGag" typeof="mw:Transclusion">14,375</span><span about="#mwt2724" typeof="mw:Entity"> </span><span about="#mwt2724">kg (31,691</span><span about="#mwt2724" typeof="mw:Entity"> </span><span about="#mwt2724">lb)</span><!-- v2 mini optimized satellites weigh ~575 kg each, 575*25=14375, round off since it's an approximation --></td>
# <td id="mwGak"><a href="https://en.wikipedia.org/wiki/Sun-synchronous_orbit" id="mwGao" rel="mw:WikiLink" title="Sun-synchronous orbit">SSO</a></td>
# <td id="mwGas"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGaw" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2725" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGa0" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2726" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[Of Course I Still Love You|OCISLY]])"]}' id="mwGa4" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/Of_Course_I_Still_Love_You" rel="mw:WikiLink" title="Of Course I Still Love You">OCISLY</a>)</td></tr>
# <tr id="mwGa8">
# <td colspan="9" id="mwGbA">Launch of 25 Starlink v2<span about="#mwt2727" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGbE" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini satellites to a <span about="#mwt2728" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"281"},"2":{"wt":"km"}},"i":0}}]}' id="mwGbI" typeof="mw:Transclusion">281</span><span about="#mwt2728" typeof="mw:Entity"> </span><span about="#mwt2728">km (175</span><span about="#mwt2728" typeof="mw:Entity"> </span><span about="#mwt2728">mi)</span> orbit at an inclination of 97° to expand internet constellation.</td></tr>
# <tr id="F9-592">
# <th id="mwGbM" rowspan="2" scope="row" style="text-align:center;">592</th>
# <td id="mwGbQ"><span about="#mwt2729" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"January 25, 2026"}},"i":0}}]}' data-sort-value="000000002026-01-25-0000" id="mwGbU" style="white-space:nowrap" typeof="mw:Transclusion">January 25, 2026</span><br id="mwGbY"/>17:30<sup about="#mwt2732" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-274"}}' id="cite_ref-274" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-274" id="mwGbc"><span class="mw-reflink-text" id="mwGbg"><span class="cite-bracket" id="mwGbk">[</span>263<span class="cite-bracket" id="mwGbo">]</span></span></a></sup></td>
# <td id="mwGbs"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwGbw" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt2735" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwGb0" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwGb4"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1097" id="mwGb8" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1097<span about="#mwt2734" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGcA" typeof="mw:Transclusion mw:Entity">‑</span>6</a></td>
# <td id="mwGcE"><a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Force_Base" id="mwGcI" rel="mw:WikiLink" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Launch_Complex_4" id="mwGcM" rel="mw:WikiLink" title="Vandenberg Space Launch Complex 4">SLC<span about="#mwt2737" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwGcQ" typeof="mw:Transclusion mw:Entity">‑</span>4E</a></td>
# <td id="mwGcU"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwGcY" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G17-20" id="mwGcc" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwGcg" typeof="mw:Entity"> </span>17-20</a></td>
# <td id="mwGck">~<span about="#mwt2738" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"14375"},"2":{"wt":"kg"}},"i":0}}]}' id="mwGco" typeof="mw:Transclusion">14,375</span><span about="#mwt2738" typeof="mw:Entity"> </span><span about="#mwt2738">kg (31,691</span><span about="#mwt2738" typeof="mw:Entity"> </span><span about="#mwt2738">lb)</span><!-- v2 mini optimized satellites weigh ~575 kg each, 575*25=14375, round off since it's an approximation --></td>
# <td id="mwGcs"><a href="https://en.wikipedia.org/wiki/Sun-synchronous_orbit" id="mwGcw" rel="mw:WikiLink" title="Sun-synchronous orbit">SSO</a></td>
# <td id="mwGc0"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwGc4" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt2739" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwGc8" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt2740" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[Of Course I Still Love You|OCISLY]])"]}' id="mwGdA" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/Of_Course_I_Still_Love_You" rel="mw:WikiLink" title="Of Course I Still Love You">OCISLY</a>)</td></tr>
# <tr id="mwGdE">
# ...
# <td about="#mwt3981" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[Of Course I Still Love You|OCISLY]])"]}' id="mwJZE" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/Of_Course_I_Still_Love_You" rel="mw:WikiLink" title="Of Course I Still Love You">OCISLY</a>)</td></tr>
# <tr id="mwJZI">
# <td colspan="9" id="mwJZM">Launch of 24 Starlink v2<span about="#mwt3982" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJZQ" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini satellites to a <span about="#mwt3983" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"281"},"2":{"wt":"km"}},"i":0}}]}' id="mwJZU" typeof="mw:Transclusion">281</span><span about="#mwt3983" typeof="mw:Entity"> </span><span about="#mwt3983">km (175</span><span about="#mwt3983" typeof="mw:Entity"> </span><span about="#mwt3983">mi)</span> orbit at an inclination of 97° to expand internet constellation.</td></tr>
# <tr id="F9-680">
# <th id="mwJZY" rowspan="2" scope="row" style="text-align:center;">680</th>
# <td id="mwJZc"><span about="#mwt3984" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"August 21, 2026"}},"i":0}}]}' data-sort-value="000000002026-08-21-0000" id="mwJZg" style="white-space:nowrap" typeof="mw:Transclusion">August 21, 2026</span><br id="mwJZk"/>15:14<sup about="#mwt3987" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-369"}}' id="cite_ref-369" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-369" id="mwJZo"><span class="mw-reflink-text" id="mwJZs"><span class="cite-bracket" id="mwJZw">[</span>358<span class="cite-bracket" id="mwJZ0">]</span></span></a></sup></td>
# <td id="mwJZ4"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwJZ8" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt3990" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJaA" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwJaE"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1078" id="mwJaI" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1078<span about="#mwt3989" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwJaM" typeof="mw:Transclusion mw:Entity">‑</span>30</a></td>
# <td id="mwJaQ"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwJaU" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwJaY" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt3992" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwJac" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwJag"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwJak" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G10-39" id="mwJao" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwJas" typeof="mw:Entity"> </span>10-39</a></td>
# <td id="mwJaw">~<span about="#mwt3993" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwJa0" typeof="mw:Transclusion">16,675</span><span about="#mwt3993" typeof="mw:Entity"> </span><span about="#mwt3993">kg (36,762</span><span about="#mwt3993" typeof="mw:Entity"> </span><span about="#mwt3993">lb)</span></td>
# <td id="mwJa4"><a class="mw-redirect" href="https://en.wikipedia.org/wiki/Low-earth_orbit" id="mwJa8" rel="mw:WikiLink" title="Low-earth orbit">LEO</a></td>
# <td id="mwJbA"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwJbE" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt3994" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwJbI" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt3995" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[A Shortfall of Gravitas|ASOG]])"]}' id="mwJbM" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/A_Shortfall_of_Gravitas" rel="mw:WikiLink" title="A Shortfall of Gravitas">ASOG</a>)</td></tr>
# <tr id="mwJbQ">
# <td colspan="9" id="mwJbU">Launch of 29 Starlink v2<span about="#mwt3996" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJbY" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini satellites to a <span about="#mwt3997" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"281"},"2":{"wt":"km"}},"i":0}}]}' id="mwJbc" typeof="mw:Transclusion">281</span><span about="#mwt3997" typeof="mw:Entity"> </span><span about="#mwt3997">km (175</span><span about="#mwt3997" typeof="mw:Entity"> </span><span about="#mwt3997">mi)</span> orbit at an inclination of 53° to expand internet constellation. 1st time flying a fairing half for the 40th time, becoming the most flown rocket stage to space.</td></tr>
# <tr id="F9-681">
# <th id="mwJbg" rowspan="2" scope="row" style="text-align:center;">681</th>
# <td id="mwJbk"><span about="#mwt3998" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"August 22, 2026"}},"i":0}}]}' data-sort-value="000000002026-08-22-0000" id="mwJbo" style="white-space:nowrap" typeof="mw:Transclusion">August 22, 2026</span><br id="mwJbs"/>07:25<sup about="#mwt4001" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-370"}}' id="cite_ref-370" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-370" id="mwJbw"><span class="mw-reflink-text" id="mwJb0"><span class="cite-bracket" id="mwJb4">[</span>359<span class="cite-bracket" id="mwJb8">]</span></span></a></sup></td>
# <td id="mwJcA"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwJcE" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt4004" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJcI" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwJcM"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1100" id="mwJcQ" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1100<span about="#mwt4003" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwJcU" typeof="mw:Transclusion mw:Entity">‑</span>9</a></td>
# <td id="mwJcY"><a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Force_Base" id="mwJcc" rel="mw:WikiLink" title="Vandenberg Space Force Base">Vandenberg</a>, <a href="https://en.wikipedia.org/wiki/Vandenberg_Space_Launch_Complex_4" id="mwJcg" rel="mw:WikiLink" title="Vandenberg Space Launch Complex 4">SLC<span about="#mwt4006" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwJck" typeof="mw:Transclusion mw:Entity">‑</span>4E</a></td>
# <td id="mwJco"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwJcs" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G15-20" id="mwJcw" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwJc0" typeof="mw:Entity"> </span>15-20</a></td>
# <td id="mwJc4">~<span about="#mwt4007" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"15525"},"2":{"wt":"kg"}},"i":0}}]}' id="mwJc8" typeof="mw:Transclusion">15,525</span><span about="#mwt4007" typeof="mw:Entity"> </span><span about="#mwt4007">kg (34,227</span><span about="#mwt4007" typeof="mw:Entity"> </span><span about="#mwt4007">lb)</span><!-- v2 mini optimized satellites weigh ~575 kg each, 575*27=15525, round off since it's an approximation --></td>
# <td id="mwJdA"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwJdE" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwJdI"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwJdM" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt4008" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwJdQ" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt4009" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[Of Course I Still Love You|OCISLY]])"]}' id="mwJdU" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/Of_Course_I_Still_Love_You" rel="mw:WikiLink" title="Of Course I Still Love You">OCISLY</a>)</td></tr>
# <tr id="mwJdY">
# <td colspan="9" id="mwJdc">Launch of 27 Starlink v2<span about="#mwt4010" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJdg" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini satellites to a <span about="#mwt4011" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"295"},"2":{"wt":"km"}},"i":0}}]}' id="mwJdk" typeof="mw:Transclusion">295</span><span about="#mwt4011" typeof="mw:Entity"> </span><span about="#mwt4011">km (183</span><span about="#mwt4011" typeof="mw:Entity"> </span><span about="#mwt4011">mi)</span> orbit at an inclination of 70° to expand internet constellation.</td></tr>
# <tr id="F9-682">
# <th id="mwJdo" rowspan="2" scope="row" style="text-align:center;">682</th>
# <td id="mwJds"><span about="#mwt4012" data-mw='{"parts":[{"template":{"target":{"wt":"date table sorting","href":"./Template:Date_table_sorting"},"params":{"1":{"wt":"August 25, 2026"}},"i":0}}]}' data-sort-value="000000002026-08-25-0000" id="mwJdw" style="white-space:nowrap" typeof="mw:Transclusion">August 25, 2026</span><br id="mwJd0"/>09:33<sup about="#mwt4015" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-371"}}' id="cite_ref-371" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-371" id="mwJd4"><span class="mw-reflink-text" id="mwJd8"><span class="cite-bracket" id="mwJeA">[</span>360<span class="cite-bracket" id="mwJeE">]</span></span></a></sup></td>
# <td id="mwJeI"><a href="https://en.wikipedia.org/wiki/Falcon_9_Block_5" id="mwJeM" rel="mw:WikiLink" title="Falcon 9 Block 5">F9<span about="#mwt4018" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJeQ" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>B5</a><br id="mwJeU"/><a href="https://en.wikipedia.org/wiki/List_of_Falcon_9_first-stage_boosters#B1067" id="mwJeY" rel="mw:WikiLink" title="List of Falcon 9 first-stage boosters">B1067<span about="#mwt4017" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwJec" typeof="mw:Transclusion mw:Entity">‑</span>37</a></td>
# <td id="mwJeg"><a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Force_Station" id="mwJek" rel="mw:WikiLink" title="Cape Canaveral Space Force Station">Cape Canaveral</a>, <a href="https://en.wikipedia.org/wiki/Cape_Canaveral_Space_Launch_Complex_40" id="mwJeo" rel="mw:WikiLink" title="Cape Canaveral Space Launch Complex 40">SLC<span about="#mwt4020" data-mw='{"parts":[{"template":{"target":{"wt":"nbhyph","href":"./Template:Nbhyph"},"params":{},"i":0}}]}' id="mwJes" typeof="mw:Transclusion mw:Entity">‑</span>40</a></td>
# <td id="mwJew"><a href="https://en.wikipedia.org/wiki/Starlink" id="mwJe0" rel="mw:WikiLink" title="Starlink">Starlink</a>: <a href="https://en.wikipedia.org/wiki/List_of_Starlink_and_Starshield_launches#G10-49" id="mwJe4" rel="mw:WikiLink" title="List of Starlink and Starshield launches">Group<span id="mwJe8" typeof="mw:Entity"> </span>10-49</a></td>
# <td id="mwJfA">~<span about="#mwt4021" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"16675"},"2":{"wt":"kg"}},"i":0}}]}' id="mwJfE" typeof="mw:Transclusion">16,675</span><span about="#mwt4021" typeof="mw:Entity"> </span><span about="#mwt4021">kg (36,762</span><span about="#mwt4021" typeof="mw:Entity"> </span><span about="#mwt4021">lb)</span></td>
# <td id="mwJfI"><a href="https://en.wikipedia.org/wiki/Low_Earth_orbit" id="mwJfM" rel="mw:WikiLink" title="Low Earth orbit">LEO</a></td>
# <td id="mwJfQ"><a href="https://en.wikipedia.org/wiki/SpaceX" id="mwJfU" rel="mw:WikiLink" title="SpaceX">SpaceX</a></td>
# <td about="#mwt4022" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}]}' id="mwJfY" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success</td>
# <td about="#mwt4023" class="table-success" data-mw='{"parts":["| ",{"template":{"target":{"wt":"Success","href":"./Template:Success"},"params":{},"i":0}}," ([[A Shortfall of Gravitas|ASOG]])"]}' id="mwJfc" style="background: #9EFF9E; color:black; vertical-align: middle; text-align: center; " typeof="mw:Transclusion">Success (<a class="mw-redirect" href="https://en.wikipedia.org/wiki/A_Shortfall_of_Gravitas" rel="mw:WikiLink" title="A Shortfall of Gravitas">ASOG</a>)</td></tr>
# <tr id="mwJfg">
# <td colspan="9" id="mwJfk">Launch of 29 Starlink v2<span about="#mwt4024" class="nowrap" data-mw='{"parts":[{"template":{"target":{"wt":"nbsp","href":"./Template:Nbsp"},"params":{},"i":0}}]}' id="mwJfo" typeof="mw:Transclusion"><span typeof="mw:Entity"> </span></span>mini optimized satellites to a <span about="#mwt4025" data-mw='{"parts":[{"template":{"target":{"wt":"cvt","href":"./Template:Cvt"},"params":{"1":{"wt":"279"},"2":{"wt":"km"}},"i":0}}]}' id="mwJfs" typeof="mw:Transclusion">279</span><span about="#mwt4025" typeof="mw:Entity"> </span><span about="#mwt4025">km (173</span><span about="#mwt4025" typeof="mw:Entity"> </span><span about="#mwt4025">mi)</span> orbit at an inclination of 53° to expand internet constellation. First booster to fly 37 missions, new record. Falcon 9 completes 100 launches this year. Last east coast Starlink launch by Falcon 9<sup about="#mwt4028" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-372"}}' id="cite_ref-372" rel="dc:references" typeof="mw:Extension/ref"><a href="#cite_note-372" id="mwJfw"><span class="mw-reflink-text" id="mwJf0"><span class="cite-bracket" id="mwJf4">[</span>361<span class="cite-bracket" id="mwJf8">]</span></span></a></sup>.</td></tr>
# </tbody></table>

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
column_names = []

# نمر على كل عنصر th في الجدول
for th in first_launch_table.find_all('th'):
    # نستخدم الدالة الجاهزة لتنظيف الاسم
    name = extract_column_from_header(th)
    
    # إذا كان الاسم موجوداً وليس فارغاً نضعه في القائمة
    if name is not None and len(name) > 0:
        column_names.append(name)

# نطبع القائمة لنرى العناوين التي استخرجناها
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome', 'FH 12']

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome', 'FH 12']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
import pandas as pd

# 1. تصفير وإعادة بناء القاموس من جديد كلياً لمنع التكرار
launch_dict = {
    'Flight No.': [],
    'Launch site': [],
    'Date': [],
    'Time': [],
    'Version Booster': [],
    'Payload': [],
    'Payload mass': [],
    'Orbit': [],
    'Customer': [],
    'Launch outcome': [],
    'Booster landing': []
}

extracted_row = 0

# 2. استخراج البيانات مرة واحدة فقط
for table_number, table in enumerate(soup.find_all('table', class_="wikitable")):
    for rows in table.find_all("tr"):
        
        flight_number = None
        flag = False
        if rows.th and rows.th.string:
            flight_number = rows.th.string.strip()
            flag = flight_number.isdigit()
            
        row = rows.find_all('td')
        
        if flag and len(row) >= 8:
            extracted_row += 1
            
            # Flight Number
            launch_dict['Flight No.'].append(flight_number)
            
            # Date & Time
            datatimelist = date_time(row[0])
            launch_dict['Date'].append(datatimelist[0].strip(','))
            launch_dict['Time'].append(datatimelist[1])
            
            # Booster Version
            bv = booster_version(row[1])
            if not bv:
                bv = row[1].a.string if row[1].a else None
            launch_dict['Version Booster'].append(bv)
            
            # Launch Site
            launch_site = row[2].a.string if row[2].a else row[2].text.strip()
            launch_dict['Launch site'].append(launch_site)
            
            # Payload
            payload = row[3].a.string if row[3].a else row[3].text.strip()
            launch_dict['Payload'].append(payload)
            
            # Payload Mass
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            
            # Orbit
            orbit = row[5].a.string if row[5].a else row[5].text.strip()
            launch_dict['Orbit'].append(orbit)
            
            # Customer
            if len(row) > 6 and row[6]:
                customer = row[6].a.string if row[6].a else row[6].text.strip()
            else:
                customer = None
            launch_dict['Customer'].append(customer)
            
            # Launch Outcome
            launch_outcome = list(row[7].strings)[0] if (len(row) > 7 and row[7].strings) else None
            launch_dict['Launch outcome'].append(launch_outcome)
            
            # Booster Landing
            booster_landing = landing_status(row[8]) if len(row) > 8 else None
            launch_dict['Booster landing'].append(booster_landing)

# 3. إنشاء الـ DataFrame وتفادي التكرار
df = pd.DataFrame({ key: pd.Series(value) for key, value in launch_dict.items() })

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
# التأكد من عدد الصفوف النظيفة
print(f"Total Rows Extracted: {len(df)}")
df.head()
# Out:
# Total Rows Extracted: 265
#   Flight No.     Launch site              Date   Time Version Booster  \
# 0        418  Cape Canaveral   January 4, 2025  01:27            F9B5
# 1        419  Cape Canaveral   January 6, 2025  20:43            F9B5
# 2        420         Kennedy   January 8, 2025  15:27            F9B5
# 3        421      Vandenberg  January 10, 2025  03:53            F9B5
# 4        422  Cape Canaveral  January 10, 2025  19:11            F9B5
#
#          Payload Payload mass Orbit Customer Launch outcome Booster landing
# 0  Thuraya 4-NGS     5,000 kg   GTO  Thuraya        Success       Success (
# 1       Starlink   ~17,500 kg   LEO   SpaceX        Success       Success (
# 2       Starlink   ~16,500 kg   LEO   SpaceX        Success       Success (
# 3     Starshield            U   LEO      NRO        Success       Success (
# 4       Starlink   ~16,500 kg   LEO   SpaceX        Success       Success (

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/">Nayef Abou Tayoun</a>

# %% [markdown]
# <!--
# ## Change Log
# -->

# %% [markdown]
# <!--
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates           |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |
# -->

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
